# %% [markdown]
# # Eat Safe, Love

# %% [markdown]
# ## Part 1: Database and Jupyter Notebook Set Up

# %% [markdown]
# Import the data provided in the `establishments.json` file from your Terminal. Name the database `uk_food` and the collection `establishments`.
#
# Within this markdown cell, copy the line of text you used to import the data from your Terminal. This way, future analysts will be able to repeat your process.
#
# e.g.: Import the dataset with `YOUR IMPORT TEXT HERE`

# %%
# Import dependencies
from pymongo import MongoClient
import pprint

# %%
# Create an instance of MongoClient
mongo = MongoClient(port=27017)

# %%
# confirm that our new database was created
print(mongo.list_database_names())
# Out:
# ['admin', 'classDB', 'classroom', 'config', 'epa', 'fruitsdb', 'garden', 'local', 'met', 'petsitly_marketing', 'test', 'travel', 'uk_food']

# %% [markdown]
# I used the following Integrated Terminal command to create the uk_food database and establishments collection as well as import all 39779 documents into MongoDB:
#
# ./mongoimport.exe --type json -d uk_food -c establishments --drop --jsonArray establishments.json

# %%
# assign the uk_food database to a variable name
db = mongo['uk_food']

# %%
# review the collections in our new database
print(db.list_collection_names())
# Out:
# ['establishments']

# %%
# review a document in the establishments collection (method 1)
db.establishments.find_one()
# Out:
# {'_id': ObjectId('641490153cf154af4135f4a6'),
#  'FHRSID': 1034540,
#  'ChangesByServerID': 0,
#  'LocalAuthorityBusinessID': 'PI/000078691',
#  'BusinessName': 'The Coastguard Inn',
#  'BusinessType': 'Pub/bar/nightclub',
#  'BusinessTypeID': 7843,
#  'AddressLine1': 'The Bay',
#  'AddressLine2': 'St Margarets Bay',
#  'AddressLine3': 'Kent',
#  'AddressLine4': '',
#  'PostCode': 'CT15 6DY',
#  'Phone': '',
#  'RatingValue': '5',
#  'RatingKey': 'fhrs_5_en-gb',
#  'RatingDate': '2022-08-17T00:00:00',
#  'LocalAuthorityCode': '182',
#  'LocalAuthorityName': 'Dover',
#  'LocalAuthorityWebSite': 'http://www.dover.gov.uk/',
#  'LocalAuthorityEmailAddress': 'publicprotection@dover.gov.uk',
#  'scores': {'Hygiene': 0, 'Structural': 5, 'ConfidenceInManagement': 0},
#  'SchemeType': 'FHRS',
#  'geocode': {'longitude': '1.387974', 'latitude': '51.152225'},
#  'RightToReply': '',
#  'Distance': 4587.347174863443,
#  'NewRatingPending': False,
#  'meta': {'dataSource': None,
#   'extractDate': '0001-01-01T00:00:00',
#   'itemCount': 0,
#   'returncode': None,
#   'totalCount': 0,
#   'totalPages': 0,
#   'pageSize': 0,
#   'pageNumber': 0},
#  'links': [{'rel': 'self',
#    'href': 'https://api.ratings.food.gov.uk/establishments/1034540'}]}

# %%
# review a document in the establishments collection (method 2)
list(db.establishments.find({}).limit(1))
# Out:
# [{'_id': ObjectId('641490153cf154af4135f4a6'),
#   'FHRSID': 1034540,
#   'ChangesByServerID': 0,
#   'LocalAuthorityBusinessID': 'PI/000078691',
#   'BusinessName': 'The Coastguard Inn',
#   'BusinessType': 'Pub/bar/nightclub',
#   'BusinessTypeID': 7843,
#   'AddressLine1': 'The Bay',
#   'AddressLine2': 'St Margarets Bay',
#   'AddressLine3': 'Kent',
#   'AddressLine4': '',
#   'PostCode': 'CT15 6DY',
#   'Phone': '',
#   'RatingValue': '5',
#   'RatingKey': 'fhrs_5_en-gb',
#   'RatingDate': '2022-08-17T00:00:00',
#   'LocalAuthorityCode': '182',
#   'LocalAuthorityName': 'Dover',
#   'LocalAuthorityWebSite': 'http://www.dover.gov.uk/',
#   'LocalAuthorityEmailAddress': 'publicprotection@dover.gov.uk',
#   'scores': {'Hygiene': 0, 'Structural': 5, 'ConfidenceInManagement': 0},
#   'SchemeType': 'FHRS',
#   'geocode': {'longitude': '1.387974', 'latitude': '51.152225'},
#   'RightToReply': '',
#   'Distance': 4587.347174863443,
#   'NewRatingPending': False,
#   'meta': {'dataSource': None,
#    'extractDate': '0001-01-01T00:00:00',
#    'itemCount': 0,
#    'returncode': None,
#    'totalCount': 0,
#    'totalPages': 0,
#    'pageSize': 0,
#    'pageNumber': 0},
#   'links': [{'rel': 'self',
#     'href': 'https://api.ratings.food.gov.uk/establishments/1034540'}]}]

# %%
# assign the collection to a variable
establishments = db['establishments']
establishments
# Out:
# Collection(Database(MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True), 'uk_food'), 'establishments')

# %% [markdown]
# ## Part 2: Update the Database

# %% [markdown]
# 1. An exciting new halal restaurant just opened in Greenwich, but hasn't been rated yet. The magazine has asked you to include it in your analysis. Add the following restaurant "Penang Flavours" to the database.

# %%
# Create a dictionary for the new restaurant data
new_restaurant = {
    "BusinessName":"Penang Flavours",
    "BusinessType":"Restaurant/Cafe/Canteen",
    "BusinessTypeID":"",
    "AddressLine1":"Penang Flavours",
    "AddressLine2":"146A Plumstead Rd",
    "AddressLine3":"London",
    "AddressLine4":"",
    "PostCode":"SE18 7DY",
    "Phone":"",
    "LocalAuthorityCode":"511",
    "LocalAuthorityName":"Greenwich",
    "LocalAuthorityWebSite":"http://www.royalgreenwich.gov.uk",
    "LocalAuthorityEmailAddress":"health@royalgreenwich.gov.uk",
    "scores":{
        "Hygiene":"",
        "Structural":"",
        "ConfidenceInManagement":""
    },
    "SchemeType":"FHRS",
    "geocode":{
        "longitude":"0.08384000",
        "latitude":"51.49014200"
    },
    "RightToReply":"",
    "Distance":4623.9723280747176,
    "NewRatingPending":True
}

# %%
# Insert the new restaurant into the collection
establishments.insert_one(new_restaurant)

# %%
# Check that the new restaurant was inserted
list(establishments.find({"BusinessName":"Penang Flavours"}))
# Out:
# [{'_id': ObjectId('6414945545946d02d67c430d'),
#   'BusinessName': 'Penang Flavours',
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': '',
#   'AddressLine1': 'Penang Flavours',
#   'AddressLine2': '146A Plumstead Rd',
#   'AddressLine3': 'London',
#   'AddressLine4': '',
#   'PostCode': 'SE18 7DY',
#   'Phone': '',
#   'LocalAuthorityCode': '511',
#   'LocalAuthorityName': 'Greenwich',
#   'LocalAuthorityWebSite': 'http://www.royalgreenwich.gov.uk',
#   'LocalAuthorityEmailAddress': 'health@royalgreenwich.gov.uk',
#   'scores': {'Hygiene': '', 'Structural': '', 'ConfidenceInManagement': ''},
#   'SchemeType': 'FHRS',
#   'geocode': {'longitude': '0.08384000', 'latitude': '51.49014200'},
#   'RightToReply': '',
#   'Distance': 4623.972328074718,
#   'NewRatingPending': True}]

# %% [markdown]
# 2. Find the BusinessTypeID for "Restaurant/Cafe/Canteen" and return only the `BusinessTypeID` and `BusinessType` fields.

# %%
# Find the BusinessTypeID for "Restaurant/Cafe/Canteen" and return only the BusinessTypeID and BusinessType fields
query = {'BusinessType': 'Restaurant/Cafe/Canteen'}
fields = {'BusinessTypeID': 1, 'BusinessType': 1}
list(establishments.find(query, fields))
# Out:
# [{'_id': ObjectId('641490153cf154af4135f4a7'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('641490153cf154af4135f4aa'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('641490153cf154af4135f4ad'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('641490153cf154af4135f4af'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('641490153cf154af4135f4b0'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('641490153cf154af4135f4b2'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('641490153cf154af4135f4b4'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('641490153cf154af4135f4b5'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('641490153cf154af4135f4b8'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('641490153cf154af4135f4ba'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('641490153cf154af4135f4bb'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('641490153cf154af4135f4bf'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('641490153cf154af4135f4c2'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('641490153cf154af4135f4c4'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('641490153cf154af4135f4cb'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('641490153cf154af4135f4d6'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('641490153cf154af4135f4d7'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('641490153cf154af4135f4da'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('641490153cf154af4135f4dc'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('641490153cf154af4135f4dd'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('641490153cf154af4135f4de'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('641490153cf154af4135f4e4'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('641490153cf154af4135f4e5'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('641490153cf154af4135f4e6'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('641490153cf154af4135f4e7'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('641490153cf154af4135f4e8'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('641490153cf154af4135f4eb'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('641490153cf154af4135f4ed'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('641490153cf154af4135f4ef'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('641490153cf154af4135f4f3'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('641490153cf154af4135f4f5'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('641490153cf154af4135f4f6'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('641490153cf154af4135f4f7'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('641490153cf154af4135f4fa'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('641490153cf154af4135f4fc'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('641490153cf154af4135f4ff'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('641490153cf154af4135f50b'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('641490153cf154af4135f50c'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('641490153cf154af4135f513'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('641490153cf154af4135f514'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('641490153cf154af4135f515'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('641490153cf154af4135f518'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('641490153cf154af4135f51a'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('641490153cf154af4135f51b'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('641490153cf154af4135f520'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('641490153cf154af4135f528'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('641490153cf154af4135f52a'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('641490153cf154af4135f52b'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('641490153cf154af4135f530'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('641490153cf154af4135f531'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('641490153cf154af4135f532'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('641490153cf154af4135f534'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('641490153cf154af4135f537'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('641490153cf154af4135f538'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('641490153cf154af4135f546'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('641490153cf154af4135f548'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('641490153cf154af4135f549'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('641490153cf154af4135f54d'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('641490153cf154af4135f54f'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('641490153cf154af4135f552'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('641490153cf154af4135f553'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('641490153cf154af4135f556'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('641490153cf154af4135f55f'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('641490153cf154af4135f560'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('641490153cf154af4135f563'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('641490153cf154af4135f566'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('641490153cf154af4135f56a'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('641490153cf154af4135f56f'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('641490153cf154af4135f570'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('641490153cf154af4135f572'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('641490153cf154af4135f577'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('641490153cf154af4135f57f'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('641490153cf154af4135f581'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('641490153cf154af4135f584'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('641490153cf154af4135f590'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('641490153cf154af4135f595'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('641490153cf154af4135f596'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('641490153cf154af4135f598'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('641490153cf154af4135f59e'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('641490153cf154af4135f5a4'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('641490153cf154af4135f5a6'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('641490153cf154af4135f5ac'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('641490153cf154af4135f5ae'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('641490153cf154af4135f5b8'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('641490153cf154af4135f5ba'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('641490153cf154af4135f5bd'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('641490153cf154af4135f5c5'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('641490153cf154af4135f5c6'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('641490153cf154af4135f5c8'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('641490153cf154af4135f5cf'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('641490153cf154af4135f5d0'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('641490153cf154af4135f5d6'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('641490153cf154af4135f5dd'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('641490153cf154af4135f5de'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('641490153cf154af4135f5e0'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('641490153cf154af4135f5e3'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('641490153cf154af4135f5eb'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('641490153cf154af4135f5ec'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('641490153cf154af4135f5ed'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('641490153cf154af4135f5ef'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('641490153cf154af4135f5f1'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('641490153cf154af4135f5f2'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('641490153cf154af4135f5f6'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('641490153cf154af4135f5f7'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('641490153cf154af4135f5f8'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('641490153cf154af4135f5f9'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('641490153cf154af4135f5fa'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('641490153cf154af4135f5fd'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('641490153cf154af4135f600'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('641490153cf154af4135f603'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('641490153cf154af4135f606'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('641490153cf154af4135f60e'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('641490153cf154af4135f612'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('641490153cf154af4135f614'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('641490153cf154af4135f616'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('641490153cf154af4135f617'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('641490153cf154af4135f61e'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('641490153cf154af4135f620'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('641490153cf154af4135f622'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('641490153cf154af4135f624'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('641490153cf154af4135f626'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('641490153cf154af4135f627'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('641490153cf154af4135f62a'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('641490153cf154af4135f62d'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('641490153cf154af4135f62f'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('641490153cf154af4135f630'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('641490153cf154af4135f639'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('641490153cf154af4135f63c'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('641490153cf154af4135f63f'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('641490153cf154af4135f644'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('641490153cf154af4135f649'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('641490153cf154af4135f64f'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('641490153cf154af4135f653'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('641490153cf154af4135f654'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('641490153cf154af4135f659'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('641490153cf154af4135f65d'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('641490153cf154af4135f65f'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('641490153cf154af4135f66a'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('641490153cf154af4135f66c'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('641490153cf154af4135f66e'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('641490153cf154af4135f670'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('641490153cf154af4135f674'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('641490153cf154af4135f676'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('641490153cf154af4135f67a'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('641490153cf154af4135f697'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('641490153cf154af4135f69d'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('641490153cf154af4135f6a1'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('641490153cf154af4135f6a3'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('641490153cf154af4135f6bd'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('641490153cf154af4135f6c9'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('641490153cf154af4135f6cb'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('641490153cf154af4135f6cd'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('641490153cf154af4135f6d0'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('641490153cf154af4135f6d1'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('641490153cf154af4135f6f3'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('641490153cf154af4135f70c'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('641490153cf154af4135f710'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('641490153cf154af4135f713'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('641490153cf154af4135f719'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('641490153cf154af4135f71b'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('641490153cf154af4135f71c'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('641490153cf154af4135f720'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('641490153cf154af4135f729'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('641490153cf154af4135f73d'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('641490153cf154af4135f741'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('641490153cf154af4135f744'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('641490153cf154af4135f746'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('641490153cf154af4135f74b'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('641490153cf154af4135f74d'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('641490153cf154af4135f753'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('641490153cf154af4135f754'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('641490153cf154af4135f759'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('641490153cf154af4135f75c'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('641490153cf154af4135f75d'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('641490153cf154af4135f762'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('641490153cf154af4135f76b'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('641490153cf154af4135f76c'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('641490153cf154af4135f771'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('641490153cf154af4135f77a'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('641490153cf154af4135f77d'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('641490153cf154af4135f784'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('641490153cf154af4135f787'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('641490153cf154af4135f78d'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('641490153cf154af4135f799'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('641490153cf154af4135f79c'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('641490153cf154af4135f79f'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('641490153cf154af4135f7a1'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('641490153cf154af4135f7af'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('641490153cf154af4135f7b6'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('641490153cf154af4135f7b9'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('641490153cf154af4135f7bd'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('641490153cf154af4135f7bf'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('641490153cf154af4135f7c3'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('641490153cf154af4135f7cd'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('641490153cf154af4135f7d5'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('641490153cf154af4135f7de'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('641490153cf154af4135f7e2'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('641490153cf154af4135f7e3'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('641490153cf154af4135f7e6'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('641490153cf154af4135f7e7'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('641490153cf154af4135f7eb'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('641490153cf154af4135f7ed'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('641490153cf154af4135f7ee'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('641490153cf154af4135f7f0'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('641490153cf154af4135f7f1'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('641490153cf154af4135f7f2'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('641490153cf154af4135f7f3'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('641490153cf154af4135f7f8'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('641490153cf154af4135f7fa'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('641490153cf154af4135f7fd'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('641490153cf154af4135f801'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('641490153cf154af4135f804'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('641490153cf154af4135f805'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('641490153cf154af4135f806'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('641490153cf154af4135f80a'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('641490153cf154af4135f80b'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('641490153cf154af4135f815'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('641490153cf154af4135f816'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('641490153cf154af4135f819'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('641490153cf154af4135f81c'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('641490153cf154af4135f81d'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('641490153cf154af4135f821'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('641490153cf154af4135f823'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('641490153cf154af4135f826'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('641490153cf154af4135f827'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('641490153cf154af4135f829'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('641490153cf154af4135f82a'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('641490153cf154af4135f82c'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('641490153cf154af4135f82d'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('641490153cf154af4135f82f'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('641490153cf154af4135f834'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('641490153cf154af4135f838'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('641490153cf154af4135f83b'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('641490153cf154af4135f83f'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('641490153cf154af4135f840'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('641490153cf154af4135f846'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('641490153cf154af4135f849'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('641490153cf154af4135f84a'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('641490153cf154af4135f853'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('641490153cf154af4135f856'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('641490153cf154af4135f857'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('641490153cf154af4135f860'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('641490153cf154af4135f862'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('641490153cf154af4135f864'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('641490153cf154af4135f866'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('641490153cf154af4135f868'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('641490153cf154af4135f869'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('641490153cf154af4135f86a'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('641490153cf154af4135f870'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('641490153cf154af4135f871'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('641490153cf154af4135f873'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('641490153cf154af4135f874'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('641490153cf154af4135f875'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('641490153cf154af4135f876'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('641490153cf154af4135f87b'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('641490153cf154af4135f880'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('641490153cf154af4135f882'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('641490153cf154af4135f883'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('641490153cf154af4135f885'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('641490153cf154af4135f88e'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('641490153cf154af4135f88f'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('641490153cf154af4135f898'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('641490153cf154af4135f899'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('641490153cf154af4135f89c'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('641490153cf154af4135f89d'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('641490153cf154af4135f89e'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('641490153cf154af4135f8a0'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('641490153cf154af4135f8a3'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('641490153cf154af4135f8a4'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('641490153cf154af4135f8a6'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('641490153cf154af4135f8a7'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('641490153cf154af4135f8ae'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('641490153cf154af4135f8b1'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('641490153cf154af4135f8b7'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('641490153cf154af4135f8b9'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('641490153cf154af4135f8c3'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('641490153cf154af4135f8c4'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('641490153cf154af4135f8dc'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('641490153cf154af4135f8de'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('641490153cf154af4135f8e1'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('641490153cf154af4135f8e8'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('641490153cf154af4135f8e9'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('641490153cf154af4135f8eb'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('641490153cf154af4135f8f0'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('641490153cf154af4135f905'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('641490153cf154af4135f90d'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('641490153cf154af4135f90e'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('641490153cf154af4135f910'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('641490153cf154af4135f912'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('641490153cf154af4135f918'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('641490153cf154af4135f91f'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('641490153cf154af4135f922'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('641490153cf154af4135f923'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('641490153cf154af4135f924'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('641490153cf154af4135f925'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('641490153cf154af4135f926'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('641490153cf154af4135f929'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('641490153cf154af4135f92a'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('641490153cf154af4135f92b'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('641490153cf154af4135f92c'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('641490153cf154af4135f92d'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('641490153cf154af4135f92e'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('641490153cf154af4135f936'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('641490153cf154af4135f93d'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('641490153cf154af4135f940'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('641490153cf154af4135f944'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('641490153cf154af4135f945'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('641490153cf154af4135f946'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('641490153cf154af4135f947'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('641490153cf154af4135f948'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('641490153cf154af4135f94a'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('641490153cf154af4135f94b'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('641490153cf154af4135f94e'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('641490153cf154af4135f94f'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('641490153cf154af4135f952'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('641490153cf154af4135f955'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('641490153cf154af4135f958'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('641490153cf154af4135f95f'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('641490153cf154af4135f961'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('641490153cf154af4135f962'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('641490153cf154af4135f964'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('641490153cf154af4135f965'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('641490153cf154af4135f966'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('641490153cf154af4135f967'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('641490153cf154af4135f96c'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('641490153cf154af4135f96d'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('641490153cf154af4135f978'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('641490153cf154af4135f97a'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('641490153cf154af4135f97b'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('641490153cf154af4135f97c'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('641490153cf154af4135f97d'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('641490153cf154af4135f980'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('641490153cf154af4135f988'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('641490153cf154af4135f98d'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('641490153cf154af4135f98f'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('641490153cf154af4135f994'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('641490153cf154af4135f995'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('641490153cf154af4135f999'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('641490153cf154af4135f99c'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('641490153cf154af4135f9a0'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('641490153cf154af4135f9a1'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('641490153cf154af4135f9a9'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('641490153cf154af4135f9af'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('641490153cf154af4135f9b6'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('641490153cf154af4135f9ba'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('641490153cf154af4135f9bc'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('641490153cf154af4135f9bd'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('641490153cf154af4135f9c5'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('641490153cf154af4135f9c8'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('641490153cf154af4135f9ca'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('641490153cf154af4135f9d1'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('641490153cf154af4135f9d5'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('641490153cf154af4135f9d7'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('641490153cf154af4135f9d9'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('641490153cf154af4135f9db'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('641490153cf154af4135f9dc'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('641490153cf154af4135f9e1'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('641490153cf154af4135f9e6'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('641490153cf154af4135f9e8'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('641490153cf154af4135f9ec'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('641490153cf154af4135f9ed'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('641490153cf154af4135f9f3'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('641490153cf154af4135f9f6'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('641490153cf154af4135f9fd'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('641490153cf154af4135f9fe'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('641490153cf154af4135f9ff'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('641490153cf154af4135fa00'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('641490153cf154af4135fa01'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('641490153cf154af4135fa03'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('641490153cf154af4135fa04'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('641490153cf154af4135fa06'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('641490153cf154af4135fa07'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('641490153cf154af4135fa09'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('641490153cf154af4135fa0a'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('641490153cf154af4135fa0c'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('641490153cf154af4135fa0d'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('641490153cf154af4135fa0e'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('641490153cf154af4135fa0f'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('641490153cf154af4135fa10'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('641490153cf154af4135fa12'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('641490153cf154af4135fa15'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('641490153cf154af4135fa16'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('641490153cf154af4135fa17'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('641490153cf154af4135fa19'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('641490153cf154af4135fa1a'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('641490153cf154af4135fa1c'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('641490153cf154af4135fa1e'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('641490153cf154af4135fa21'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('641490153cf154af4135fa22'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('641490153cf154af4135fa23'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('641490153cf154af4135fa24'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('641490153cf154af4135fa2d'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('641490153cf154af4135fa2e'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('641490153cf154af4135fa2f'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('641490153cf154af4135fa30'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('641490153cf154af4135fa31'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('641490153cf154af4135fa39'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('641490153cf154af4135fa3a'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('641490153cf154af4135fa3d'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('641490153cf154af4135fa3f'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('641490153cf154af4135fa41'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('641490153cf154af4135fa42'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('641490153cf154af4135fa49'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('641490153cf154af4135fa4b'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('641490153cf154af4135fa53'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('641490153cf154af4135fa54'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('641490153cf154af4135fa62'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('641490153cf154af4135fa6a'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('641490153cf154af4135fa73'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('641490153cf154af4135fa78'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('641490153cf154af4135fa7a'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('641490153cf154af4135fa7d'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('641490153cf154af4135fa7f'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('641490153cf154af4135fa87'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
# ...
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('641490153cf154af413600e8'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('641490153cf154af413600e9'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('641490153cf154af413600ea'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('641490153cf154af413600f0'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('641490153cf154af413600f3'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('641490153cf154af41360102'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('641490153cf154af41360103'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('641490153cf154af41360108'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('641490153cf154af4136010a'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('641490153cf154af41360113'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('641490153cf154af41360117'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('641490153cf154af4136011a'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('641490153cf154af41360124'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('641490153cf154af4136012a'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('641490153cf154af41360132'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('641490153cf154af4136013a'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('641490153cf154af41360140'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('641490153cf154af41360142'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('641490153cf154af41360148'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('641490153cf154af4136015e'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('641490153cf154af4136015f'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('641490153cf154af41360165'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('641490153cf154af41360166'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('641490153cf154af41360167'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('641490153cf154af41360169'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('641490153cf154af4136016c'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('641490153cf154af41360170'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('641490153cf154af4136017a'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('641490153cf154af4136017f'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('641490153cf154af41360187'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('641490153cf154af4136018b'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('641490153cf154af41360194'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('641490153cf154af4136019a'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('641490153cf154af413601a8'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('641490153cf154af413601b3'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('641490153cf154af413601ba'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('641490153cf154af413601bb'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('641490153cf154af413601c4'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('641490153cf154af413601c6'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('641490153cf154af413601cc'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('641490153cf154af413601d0'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('641490153cf154af413601d4'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('641490153cf154af413601e0'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('641490153cf154af413601e1'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('641490153cf154af413601e9'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('641490153cf154af413601ea'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('641490153cf154af413601ed'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('641490153cf154af413601f0'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('641490153cf154af413601f1'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('641490153cf154af413601f7'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('641490153cf154af41360207'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('641490153cf154af4136021c'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('641490153cf154af41360224'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('641490153cf154af41360225'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('641490153cf154af41360226'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('641490153cf154af4136022c'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('641490153cf154af4136022d'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('641490153cf154af41360231'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('641490153cf154af41360232'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('641490153cf154af41360235'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('641490153cf154af4136023a'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('641490153cf154af4136023c'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('641490153cf154af41360248'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('641490153cf154af41360249'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('641490153cf154af4136024b'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('641490153cf154af4136024d'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('641490153cf154af4136024f'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('641490153cf154af41360250'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('641490153cf154af41360253'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('641490153cf154af41360257'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('641490153cf154af41360258'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('641490153cf154af41360259'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('641490153cf154af4136025a'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('641490153cf154af4136025c'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('641490153cf154af4136025e'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('641490153cf154af4136025f'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('641490153cf154af41360260'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('641490153cf154af41360263'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('641490153cf154af41360265'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('641490153cf154af41360266'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('641490153cf154af41360269'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('641490153cf154af4136026f'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('641490153cf154af41360275'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('641490153cf154af4136027e'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('641490153cf154af4136027f'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('641490153cf154af41360281'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('641490153cf154af41360285'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('641490153cf154af41360288'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('641490153cf154af4136028c'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('641490153cf154af4136028e'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('641490153cf154af41360290'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('641490153cf154af41360291'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('641490153cf154af41360292'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('641490153cf154af41360299'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('641490153cf154af4136029c'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('641490153cf154af4136029d'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('641490153cf154af4136029e'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('641490153cf154af413602aa'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('641490153cf154af413602ad'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('641490153cf154af413602ae'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('641490153cf154af413602b0'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('641490153cf154af413602b1'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('641490153cf154af413602b5'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('641490153cf154af413602b8'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('641490153cf154af413602b9'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('641490153cf154af413602ba'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('641490153cf154af413602bc'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('641490153cf154af413602bd'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('641490153cf154af413602bf'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('641490153cf154af413602c3'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('641490153cf154af413602c5'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('641490153cf154af413602c7'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('641490153cf154af413602ca'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('641490153cf154af413602cc'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('641490153cf154af413602cd'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('641490153cf154af413602d0'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('641490153cf154af413602d3'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('641490153cf154af413602d5'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('641490153cf154af413602dc'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('641490153cf154af413602df'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('641490153cf154af413602e4'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('641490153cf154af413602e6'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('641490153cf154af413602e7'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('641490153cf154af413602e9'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('641490153cf154af413602ea'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('641490153cf154af413602ec'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('641490153cf154af413602ee'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('641490153cf154af413602f1'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('641490153cf154af413602f4'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('641490153cf154af413602f5'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('641490153cf154af413602f6'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('641490153cf154af413602fa'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('641490153cf154af413602fb'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('641490153cf154af413602fc'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('641490153cf154af413602fd'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('641490153cf154af41360301'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('641490153cf154af41360302'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  ...]

# %% [markdown]
# 3. Update the new restaurant with the `BusinessTypeID` you found.

# %%
# Update the new restaurant with the correct BusinessTypeID
filter = {'BusinessName':'Penang Flavours'}
new_value = {'$set': {'BusinessTypeID': '1'}}
establishments.update_one(filter, new_value)

# %%
# Confirm that the new restaurant was updated
list(establishments.find({"BusinessName":"Penang Flavours"}))
# Out:
# [{'_id': ObjectId('6414945545946d02d67c430d'),
#   'BusinessName': 'Penang Flavours',
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': '1',
#   'AddressLine1': 'Penang Flavours',
#   'AddressLine2': '146A Plumstead Rd',
#   'AddressLine3': 'London',
#   'AddressLine4': '',
#   'PostCode': 'SE18 7DY',
#   'Phone': '',
#   'LocalAuthorityCode': '511',
#   'LocalAuthorityName': 'Greenwich',
#   'LocalAuthorityWebSite': 'http://www.royalgreenwich.gov.uk',
#   'LocalAuthorityEmailAddress': 'health@royalgreenwich.gov.uk',
#   'scores': {'Hygiene': '', 'Structural': '', 'ConfidenceInManagement': ''},
#   'SchemeType': 'FHRS',
#   'geocode': {'longitude': '0.08384000', 'latitude': '51.49014200'},
#   'RightToReply': '',
#   'Distance': 4623.972328074718,
#   'NewRatingPending': True}]

# %% [markdown]
# 4. The magazine is not interested in any establishments in Dover, so check how many documents contain the Dover Local Authority. Then, remove any establishments within the Dover Local Authority from the database, and check the number of documents to ensure they were deleted.

# %%
# Find how many documents have LocalAuthorityName as "Dover"
establishments.count_documents({'LocalAuthorityName': 'Dover'})
# Out:
# 994

# %%
# Delete all documents where LocalAuthorityName is "Dover"
establishments.delete_many({'LocalAuthorityName': 'Dover'})

# %%
# Check if any remaining documents include Dover
establishments.count_documents({'LocalAuthorityName': 'Dover'})
# Out:
# 0

# %%
# Check that other documents remain with 'find_one'
establishments.find_one()
# Out:
# {'_id': ObjectId('641490153cf154af4135f78d'),
#  'FHRSID': 1043695,
#  'ChangesByServerID': 0,
#  'LocalAuthorityBusinessID': 'PI/000073616',
#  'BusinessName': 'The Pavilion',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  'AddressLine1': 'East Cliff Pavilion',
#  'AddressLine2': 'Wear Bay Road',
#  'AddressLine3': 'Folkestone',
#  'AddressLine4': 'Kent',
#  'PostCode': 'CT19 6BL',
#  'Phone': '',
#  'RatingValue': '5',
#  'RatingKey': 'fhrs_5_en-gb',
#  'RatingDate': '2018-04-04T00:00:00',
#  'LocalAuthorityCode': '188',
#  'LocalAuthorityName': 'Folkestone and Hythe',
#  'LocalAuthorityWebSite': 'http://www.folkestone-hythe.gov.uk',
#  'LocalAuthorityEmailAddress': 'foodteam@folkestone-hythe.gov.uk',
#  'scores': {'Hygiene': 5, 'Structural': 5, 'ConfidenceInManagement': 5},
#  'SchemeType': 'FHRS',
#  'geocode': {'longitude': '1.195625', 'latitude': '51.083812'},
#  'RightToReply': '',
#  'Distance': 4591.765489457773,
#  'NewRatingPending': False,
#  'meta': {'dataSource': None,
#   'extractDate': '0001-01-01T00:00:00',
#   'itemCount': 0,
#   'returncode': None,
#   'totalCount': 0,
#   'totalPages': 0,
#   'pageSize': 0,
#   'pageNumber': 0},
#  'links': [{'rel': 'self',
#    'href': 'https://api.ratings.food.gov.uk/establishments/1043695'}]}

# %% [markdown]
# 5. Some of the number values are stored as strings, when they should be stored as numbers. Use `update_many` to convert `latitude` and `longitude` to decimal numbers.

# %%
# Change the data type from String to Decimal for longitude

# %%
# Change the data type from String to Decimal for latitude

# %%
# Check that the coordinates are now numbers
